# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/home/mg/Documents/ML/archive/ds_salaries.csv');

# %%
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df=data.copy()

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
# 6       2023               SE              FT         Applied Scientist
# 7       2023               SE              FT            Data Scientist
# 8       2023               SE              FT            Data Scientist
# 9       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# ...

# %%
print(df.shape)
# Out:
# (3755, 11)

# %%
print(df.dtypes)
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.iloc[1:5,1:4]
# Out:
#   experience_level employment_type       job_title
# 1               MI              CT     ML Engineer
# 2               MI              CT     ML Engineer
# 3               SE              FT  Data Scientist
# 4               SE              FT  Data Scientist

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df.drop(8,inplace=True)

# %%
df.index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    7,    9,   10,
#             ...
#             3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, 3753, 3754],
#            dtype='int64', length=3754)

# %%
df.drop(df.index[0],inplace=True)

# %%
print(df.iloc[0])
# Out:
# work_year                    2023
# experience_level               MI
# employment_type                CT
# job_title             ML Engineer
# salary                      30000
# salary_currency               USD
# salary_in_usd               30000
# employee_residence             US
# remote_ratio                  100
# company_location               US
# company_size                    S
# Name: 1, dtype: object

# %%
df.reset_index(drop=True,inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=3753, step=1)

# %%
df.drop('salary_in_usd',axis=1,inplace=True)

# %%
del df['employment_type']

# %%
df
# Out:
#       work_year experience_level                 job_title   salary  \
# 0          2023               MI               ML Engineer    30000
# 1          2023               MI               ML Engineer    25500
# 2          2023               SE            Data Scientist   175000
# 3          2023               SE            Data Scientist   120000
# 4          2023               SE         Applied Scientist   222200
# ...         ...              ...                       ...      ...
# 3748       2020               SE            Data Scientist   412000
# 3749       2021               MI  Principal Data Scientist   151000
# 3750       2020               EN            Data Scientist   105000
# 3751       2020               EN     Business Data Analyst   100000
# 3752       2021               SE      Data Science Manager  7000000
#
#      salary_currency employee_residence  remote_ratio company_location  \
# 0                USD                 US           100               US
# ...

# %%
df.tail()
# Out:
#       work_year experience_level                 job_title   salary  \
# 3748       2020               SE            Data Scientist   412000
# 3749       2021               MI  Principal Data Scientist   151000
# 3750       2020               EN            Data Scientist   105000
# 3751       2020               EN     Business Data Analyst   100000
# 3752       2021               SE      Data Science Manager  7000000
#
#      salary_currency employee_residence  remote_ratio company_location  \
# 3748             USD                 US           100               US
# 3749             USD                 US           100               US
# 3750             USD                 US           100               US
# 3751             USD                 US           100               US
# 3752             INR                 IN            50               IN
#
#      company_size
# 3748            L
# 3749            L
# 3750            S
# 3751            L
# 3752            L

# %%
df.describe()
# Out:
#          work_year        salary  remote_ratio
# count  3753.000000  3.753000e+03   3753.000000
# mean   2022.373301  1.907383e+05     46.269651
# std       0.691481  6.718526e+05     48.588211
# min    2020.000000  6.000000e+03      0.000000
# 25%    2022.000000  1.000000e+05      0.000000
# 50%    2022.000000  1.380000e+05      0.000000
# 75%    2023.000000  1.800000e+05    100.000000
# max    2023.000000  3.040000e+07    100.000000

# %%
def f(s):
    if s=="US":
        return 0
    else:
        return 1
df["emp_residence"]=df.employee_residence.apply(f)
df.head()
# Out:
#    work_year experience_level          job_title  salary salary_currency  \
# 0       2023               MI        ML Engineer   30000             USD
# 1       2023               MI        ML Engineer   25500             USD
# 2       2023               SE     Data Scientist  175000             USD
# 3       2023               SE     Data Scientist  120000             USD
# 4       2023               SE  Applied Scientist  222200             USD
#
#   employee_residence  remote_ratio company_location company_size  \
# 0                 US           100               US            S
# 1                 US           100               US            S
# 2                 CA           100               CA            M
# 3                 CA           100               CA            M
# 4                 US             0               US            L
#
#    emp_residence
# 0              0
# 1              0
# 2              1
# 3              1
# 4              0
